# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/IDSNlogo.png" width = 400> </a>
#
# <h4 align=center><font size = 6><em>Capstone Project - The Battle of Neighborhoods (Week 1)</font></h4>

# %% [markdown]
#  **INTRODUCTION**

# %% [markdown]
# In this assignment we will use **Foursquare API** to explore the nearby **Japanese** and **Italian** restaurants of  New York City and compare the ratings and tips of these restaurants.
#
# Finally, we will use the Folium library to visualize the both restaurants in New York City.
#
# We will use construct URL to send a request to API to explore venues, geographical location using Foursquare and visualize results

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.52)
# Requirement already satisfied: folium==0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.25.1)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.16.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (3.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (2.0.1)
# Folium installed
# Libraries imported.

# %% [markdown]
# **Define Foursquare Credentials and Version**

# %%
CLIENT_ID = 'AMDLDMMIEWL1QOOBEGJ5JNHSS2NBE4H0BK230CRAYNIDBGXQ' # your Foursquare ID
CLIENT_SECRET = 'A4UWUFMDVX1MX0JECHVUZZNOWVGCAE5E2JONLHRO1VVUPOY1' # your Foursquare Secret
ACCESS_TOKEN = '' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AMDLDMMIEWL1QOOBEGJ5JNHSS2NBE4H0BK230CRAYNIDBGXQ
# CLIENT_SECRET:A4UWUFMDVX1MX0JECHVUZZNOWVGCAE5E2JONLHRO1VVUPOY1

# %% [markdown]
# **Let's  assume that you were staying at the Conrad hotel in New York .So let's start by converting the  Hotel's address to its latitude and longitude coordinates.**

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %% [markdown]
# ## **1) Search  for a specific venue category for japanese food.**
# #### **Lets define a query to search for japanese food that is within 800mts from Conrad Hotel.**

# %%
search_query = 'Japanese'
radius = 800
print(search_query + ' .... OK!')
# Out:
# Japanese .... OK!

# %% [markdown]
# **Define the corresponding URL**

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AMDLDMMIEWL1QOOBEGJ5JNHSS2NBE4H0BK230CRAYNIDBGXQ&client_secret=A4UWUFMDVX1MX0JECHVUZZNOWVGCAE5E2JONLHRO1VVUPOY1&ll=40.7149555,-74.0153365&oauth_token=&v=20180604&query=Japanese&radius=800&limit=30'

# %% [markdown]
# **Send the GET Request and examine the results**

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60e074ae3088be315f430efa'},
#  'response': {'venues': [{'id': '4b78ac62f964a52047dd2ee3',
#     'name': 'Zutto Japanese American Pub',
#     'location': {'address': '77 Hudson St',
#      'crossStreet': 'Harrison St and Worth St.',
#      'lat': 40.7185655837561,
#      'lng': -74.00891273768076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7185655837561,
#        'lng': -74.00891273768076},
#       {'label': 'entrance', 'lat': 40.718459, 'lng': -74.009006}],
#      'distance': 674,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['77 Hudson St (Harrison St and Worth St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '867441',
#      'url': 'https://www.seamless.com/menu/zutto-77-hudson-st-new-york/867441?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=867441',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '42701794'},
#     'referralId': 'v-1625322670',
#     'hasPerk': False},
#    {'id': '4e4e4c34bd4101d0d7a71f7d',
#     'name': 'Aoi Japanese Restaurant',
#     'location': {'address': '325 Broadway',
#      'lat': 40.71612035753943,
#      'lng': -74.00527813637986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71612035753943,
#        'lng': -74.00527813637986}],
#      'distance': 858,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['325 Broadway',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625322670',
#     'hasPerk': False},
#    {'id': '5464f27c498e2e01c60151af',
#     'name': 'Kaede Japanese Restaurant',
#     'location': {'address': '90 Chambers St',
#      'lat': 40.71462286117167,
#      'lng': -74.00727042164348,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71462286117167,
#        'lng': -74.00727042164348}],
#      'distance': 681,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['90 Chambers St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2398298',
#      'url': 'https://www.seamless.com/menu/kaede-90-chambers-st-new-york/2398298?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2398298',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625322670',
#     'hasPerk': False},
#    {'id': '4af5d65ff964a52091fd21e3',
#     'name': 'Korin',
#     'location': {'address': '57 Warren St',
#      'crossStreet': 'Church St',
#      'lat': 40.71482437714839,
#      'lng': -74.00940425461492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71482437714839,
#        'lng': -74.00940425461492},
#       {'label': 'entrance', 'lat': 40.714727, 'lng': -74.009399}],
#      'distance': 500,
#      'postalCode': '10007',
#      'cc': 'US',
#      'neighborhood': 'Tribeca',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['57 Warren St (Church St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '33104775'},
#     'referralId': 'v-1625322670',
#     'hasPerk': False},
#    {'id': '4a779005f964a520cee41fe3',
#     'name': 'Tokyo Bay',
#     'location': {'address': '183 Duane St',
#      'crossStreet': 'btw Greenwich & Hudson',
#      'lat': 40.71741957382734,
#      'lng': -74.01026480981929,
#      'distance': 508,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['183 Duane St (btw Greenwich & Hudson)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625322670',
#     'hasPerk': False}]}}

# %% [markdown]
# **Get relevant part of JSON and transform it into a pandas dataframe**

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#                          id                         name  \
# 0  4b78ac62f964a52047dd2ee3  Zutto Japanese American Pub
# 1  4e4e4c34bd4101d0d7a71f7d      Aoi Japanese Restaurant
# 2  5464f27c498e2e01c60151af    Kaede Japanese Restaurant
# 3  4af5d65ff964a52091fd21e3                        Korin
# 4  4a779005f964a520cee41fe3                    Tokyo Bay
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...  v-1625322670    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1625322670    False
# 2  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1625322670    False
# 3  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...  v-1625322670    False
# 4  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1625322670    False
#
#   location.address       location.crossStreet  location.lat  location.lng  \
# 0     77 Hudson St  Harrison St and Worth St.     40.718566    -74.008913
# 1     325 Broadway                        NaN     40.716120    -74.005278
# 2   90 Chambers St                        NaN     40.714623    -74.007270
# 3     57 Warren St                  Church St     40.714824    -74.009404
# 4     183 Duane St     btw Greenwich & Hudson     40.717420    -74.010265
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.7185655837561,...                674
# 1  [{'label': 'display', 'lat': 40.71612035753943...                858
# 2  [{'label': 'display', 'lat': 40.71462286117167...                681
# 3  [{'label': 'display', 'lat': 40.71482437714839...                500
# 4                                                NaN                508
#
#   location.postalCode location.cc location.city location.state  \
# 0               10013          US      New York             NY
# 1               10007          US      New York             NY
# 2               10007          US      New York             NY
# 3               10007          US      New York             NY
# 4               10013          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [77 Hudson St (Harrison St and Worth St.), New...
# 1    United States  [325 Broadway, New York, NY 10007, United States]
# 2    United States  [90 Chambers St, New York, NY 10007, United St...
# 3    United States  [57 Warren St (Church St), New York, NY 10007,...
# 4    United States  [183 Duane St (btw Greenwich & Hudson), New Yo...
#
#   delivery.id                                       delivery.url  \
# 0      867441  https://www.seamless.com/menu/zutto-77-hudson-...
# 1         NaN                                                NaN
# 2     2398298  https://www.seamless.com/menu/kaede-90-chamber...
# 3         NaN                                                NaN
# 4         NaN                                                NaN
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0               seamless  https://fastly.4sqi.net/img/general/cap/
# 1                    NaN                                       NaN
# 2               seamless  https://fastly.4sqi.net/img/general/cap/
# 3                    NaN                                       NaN
# 4                    NaN                                       NaN
#
#   delivery.provider.icon.sizes               delivery.provider.icon.name  \
# 0                     [40, 50]  /delivery_provider_seamless_20180129.png
# 1                          NaN                                       NaN
# 2                     [40, 50]  /delivery_provider_seamless_20180129.png
# 3                          NaN                                       NaN
# 4                          NaN                                       NaN
#
#   venuePage.id location.neighborhood
# 0     42701794                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3     33104775               Tribeca
# 4          NaN                   NaN

# %% [markdown]
# **Define information of interest and filter dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                           name              categories         address  \
# 0  Zutto Japanese American Pub            Noodle House    77 Hudson St
# 1      Aoi Japanese Restaurant     Japanese Restaurant    325 Broadway
# 2    Kaede Japanese Restaurant     Japanese Restaurant  90 Chambers St
# 3                        Korin  Furniture / Home Store    57 Warren St
# 4                    Tokyo Bay        Sushi Restaurant    183 Duane St
#
#                  crossStreet        lat        lng  \
# 0  Harrison St and Worth St.  40.718566 -74.008913
# 1                        NaN  40.716120 -74.005278
# 2                        NaN  40.714623 -74.007270
# 3                  Church St  40.714824 -74.009404
# 4     btw Greenwich & Hudson  40.717420 -74.010265
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.7185655837561,...       674      10013  US
# 1  [{'label': 'display', 'lat': 40.71612035753943...       858      10007  US
# 2  [{'label': 'display', 'lat': 40.71462286117167...       681      10007  US
# 3  [{'label': 'display', 'lat': 40.71482437714839...       500      10007  US
# 4                                                NaN       508      10013  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
# 2  New York    NY  United States
# 3  New York    NY  United States
# 4  New York    NY  United States
#
#                                     formattedAddress neighborhood  \
# 0  [77 Hudson St (Harrison St and Worth St.), New...          NaN
# 1  [325 Broadway, New York, NY 10007, United States]          NaN
# 2  [90 Chambers St, New York, NY 10007, United St...          NaN
# 3  [57 Warren St (Church St), New York, NY 10007,...      Tribeca
# 4  [183 Duane St (btw Greenwich & Hudson), New Yo...          NaN
#
#                          id
# 0  4b78ac62f964a52047dd2ee3
# 1  4e4e4c34bd4101d0d7a71f7d
# 2  5464f27c498e2e01c60151af
# 3  4af5d65ff964a52091fd21e3
# 4  4a779005f964a520cee41fe3

# %% [markdown]
# **Let's visualize the Japanese restaurants that are nearby**

# %%
dataframe_filtered.name
# Out:
# 0    Zutto Japanese American Pub
# 1        Aoi Japanese Restaurant
# 2      Kaede Japanese Restaurant
# 3                          Korin
# 4                      Tokyo Bay
# Name: name, dtype: object

# %% [markdown]
# #### A. Let's explore the closest Japanese restaurant -- _Tokyo Bay_

# %%
venue_id = '4a779005f964a520cee41fe3' # ID of Tokyo Bay, Japanese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4a779005f964a520cee41fe3?client_id=AMDLDMMIEWL1QOOBEGJ5JNHSS2NBE4H0BK230CRAYNIDBGXQ&client_secret=A4UWUFMDVX1MX0JECHVUZZNOWVGCAE5E2JONLHRO1VVUPOY1&oauth_token=&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4a779005f964a520cee41fe3',
#  'name': 'Tokyo Bay',
#  'contact': {'phone': '2124318666', 'formattedPhone': '(212) 431-8666'},
#  'location': {'address': '183 Duane St',
#   'crossStreet': 'btw Greenwich & Hudson',
#   'lat': 40.71741957382734,
#   'lng': -74.01026480981929,
#   'postalCode': '10013',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['183 Duane St (btw Greenwich & Hudson)',
#    'New York, NY 10013',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/tokyo-bay/4a779005f964a520cee41fe3',
#  'categories': [{'id': '4bf58dd8d48988d1d2941735',
#    'name': 'Sushi Restaurant',
#    'pluralName': 'Sushi Restaurants',
#    'shortName': 'Sushi',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 19},
#  'url': 'http://tokyobaynyc.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 5,
#   'groups': [{'type': 'others',
#     'count': 5,
#     'items': [{'firstName': 'Julio', 'lastName': 'G', 'countryCode': 'US'},
#      {'firstName': 'Steven', 'lastName': 'S', 'countryCode': 'US'},
#      {'firstName': 'N', 'lastName': 'M', 'countryCode': 'US'},
#      {'firstName': 'Jin', 'countryCode': 'US'}]}],
#   'summary': '5 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.7,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 16,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/tokyo-bay/4a779005f964a520cee41fe3/menu',
#   'mobileUrl': 'https://foursquare.com/v/4a779005f964a520cee41fe3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 7,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 7,
#     'items': [{'id': '5d5c901a01e51d0008f9b40b',
#       'createdAt': 1566347290,
#       'source': {'name': 'Swarm for Android',
#        'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/4012520_XHEP1GSjX5K2fp3TGRd8rwNuPUoCpSlF5bl-oqRx54Q.jpg',
#       'width': 1425,
#       'height': 1900,
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1249349637,
#  'tips': {'count': 19,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 19,
#     'items': [{'id': '4d2f31f3bb73a090ada955dc',
#       'createdAt': 1294938611,
#       'text': 'Mediocre at best. Extremely poor service. Avoid!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4d2f31f3bb73a090ada955dc',
#       'lang': 'en',
#       'likes': {'count': 3,
#        'groups': [{'type': 'others',
#          'count': 3,
#          'items': [{'firstName': 'Jesse',
#            'lastName': 'M',
#            'countryCode': 'US'},
#           {'firstName': 'Rachel', 'lastName': 'R', 'countryCode': 'US'}]}],
#        'summary': '3 likes'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'firstName': 'Premshree',
#        'lastName': 'P',
#        'countryCode': 'US'}}]}]},
#  'shortUrl': 'http://4sq.com/7MEzyY',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 4,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 4,
#     'items': [{'id': '521ecaf111d2597673efc8f7',
#       'name': 'New york',
#       'description': '',
#       'type': 'others',
#       'user': {'firstName': 'Mirco', 'lastName': 'P', 'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/mircopasqualini/list/new-york',
#       'canonicalUrl': 'https://foursquare.com/mircopasqualini/list/new-york',
#       'createdAt': 1377749745,
#       'updatedAt': 1485525680,
#       'photo': {'id': '51ae7a8e498e8a939ef6565e',
#        'createdAt': 1370389134,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/61190_Fd-EoWuMld1br7T7l_m7EyZ7ZNRocfO6Yjl_m8IhIII.jpg',
#        'width': 720,
#        'height': 960,
#        'visibility': 'public'},
#       'followers': {'count': 2},
#       'listItems': {'count': 124,
#        'items': [{'id': 'v4a779005f964a520cee41fe3',
#          'createdAt': 1400197272}]}},
#      {'id': '4f5bf2dfe4b053fd68362746',
#       'name': 'NYC Restaurants',
#       'description': 'NYC Restaurants I have been to',
#       'type': 'others',
#       'user': {'firstName': 'Zhen', 'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/zjin/list/nyc-restaurants',
#       'canonicalUrl': 'https://foursquare.com/zjin/list/nyc-restaurants',
#       'createdAt': 1331426015,
#       'updatedAt': 1502474125,
#       'photo': {'id': '51f57615498e86675fb495ca',
#        'createdAt': 1375041045,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/6734777_9G8yu_kSAEJRm86ZHe27bZeA0u04bBZtWKqury_1NIk.jpg',
#        'width': 674,
#        'height': 930,
#        'visibility': 'public'},
#       'followers': {'count': 0},
#       'listItems': {'count': 50,
#        'items': [{'id': 'v4a779005f964a520cee41fe3',
#          'createdAt': 1331426399}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–4:00 PM'},
#      {'renderedTime': '6:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '7:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Fri',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '7:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]}]},
#  'bestPhoto': {'id': '5d5c901a01e51d0008f9b40b',
#   'createdAt': 1566347290,
#   'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/4012520_XHEP1GSjX5K2fp3TGRd8rwNuPUoCpSlF5bl-oqRx54Q.jpg',
#   'width': 1425,
#   'height': 1900,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '5d5c901a01e51d0008f9b40b',
#    'value': -7821096},
#   'highlightTextColor': {'photoId': '5d5c901a01e51d0008f9b40b',
#    'value': -16777216},
#   'algoVersion': 3}}

# %% [markdown]
# #### B. Get the closest venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.7

# %%
venue_id = '5464f27c498e2e01c60151af' # ID of Kaede Japanese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.7

# %%
venue_id = '4b78ac62f964a52047dd2ee3' # ID of 4b78ac62f964a52047dd2ee3
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.5

# %% [markdown]
# Other restuarents which are not rated are deleted after checking

# %% [markdown]
# #### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 144

# %% [markdown]
# ## **2) Search  for a specific venue category for Mexican food.**
# #### **Lets define a query to search for japanese food that is within 800mts from Conrad Hotel.**

# %%
search_query = 'Mexican'
radius = 800
print(search_query + ' .... OK!')
# Out:
# Mexican .... OK!

# %% [markdown]
# **Define the corresponding URL**

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AMDLDMMIEWL1QOOBEGJ5JNHSS2NBE4H0BK230CRAYNIDBGXQ&client_secret=A4UWUFMDVX1MX0JECHVUZZNOWVGCAE5E2JONLHRO1VVUPOY1&ll=40.7149555,-74.0153365&oauth_token=&v=20180604&query=Mexican&radius=800&limit=30'

# %% [markdown]
# **Send the GET Request and examine the results**

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60e087b42fef665e5c7caad5'},
#  'response': {'venues': [{'id': '4bd716bd6798ef3b382c668d',
#     'name': 'Chipotle Mexican Grill',
#     'location': {'address': '111 Fulton St',
#      'crossStreet': 'at William St',
#      'lat': 40.7099267,
#      'lng': -74.0065609,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7099267,
#        'lng': -74.0065609}],
#      'distance': 928,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['111 Fulton St (at William St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '51b3b7da498efda7cefb2660',
#     'name': "Dahlia's Mexican Restaurant",
#     'location': {'address': '353 Greenwich St',
#      'lat': 40.718753859488345,
#      'lng': -74.010337260918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718753859488345,
#        'lng': -74.010337260918}],
#      'distance': 597,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['353 Greenwich St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '88041102'},
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '554ce3f0498e5e644ef0ab8a',
#     'name': 'Chipotle Mexican Grill',
#     'location': {'address': '325 S End Ave',
#      'crossStreet': 'South End Avenue and Albany Street',
#      'lat': 40.71070271157653,
#      'lng': -74.01636963147331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71070271157653,
#        'lng': -74.01636963147331}],
#      'distance': 481,
#      'postalCode': '10280',
#      'cc': 'US',
#      'neighborhood': 'Battery Park City, New York, NY',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['325 S End Ave (South End Avenue and Albany Street)',
#       'New York, NY 10280',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '503502d6e4b0bd196609a46e',
#     'name': 'Chipotle Mexican Grill',
#     'location': {'address': '275 Greenwich St',
#      'crossStreet': 'btwn Murray & Warren St',
#      'lat': 40.715042948179274,
#      'lng': -74.01102995947537,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715042948179274,
#        'lng': -74.01102995947537},
#       {'label': 'entrance', 'lat': 40.715223, 'lng': -74.011076}],
#      'distance': 363,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['275 Greenwich St (btwn Murray & Warren St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '552e8f94498e2fd1610bbcb7',
#     'name': 'mexican boulevard',
#     'location': {'lat': 40.71858025463592,
#      'lng': -74.01222157019458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71858025463592,
#        'lng': -74.01222157019458}],
#      'distance': 481,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '4d5eb921d7206ea8b045e0f1',
#     'name': 'Tex-mexican Express',
#     'location': {'address': '63 Reade St',
#      'crossStreet': 'Broadway and church',
#      'lat': 40.71485137939453,
#      'lng': -74.00653839111328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71485137939453,
#        'lng': -74.00653839111328}],
#      'distance': 742,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['63 Reade St (Broadway and church)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2078480',
#      'url': 'https://www.seamless.com/menu/acapulco-fajita-tex-mexican-express-63-reade-street-new-york/2078480?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2078480',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '4ee8e058f790a9d738d62d70',
#     'name': 'Chipotle Mexican Grill',
#     'location': {'address': '281 Broadway',
#      'crossStreet': 'at Reade St',
#      'lat': 40.714606606499316,
#      'lng': -74.00633473282073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714606606499316,
#        'lng': -74.00633473282073}],
#      'distance': 760,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['281 Broadway (at Reade St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d153941735',
#       'name': 'Burrito Place',
#       'pluralName': 'Burrito Places',
#       'shortName': 'Burritos',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '5109475fe4b0e6d0ff2b2294',
#     'name': 'Caliente Mexican Grill',
#     'location': {'lat': 40.70869,
#      'lng': -74.01092,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70869,
#        'lng': -74.01092}],
#      'distance': 790,
#      'postalCode': '10271',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10271', 'United States']},
#     'categories': [],
#     'referralId': 'v-1625327540',
#     'hasPerk': False},
#    {'id': '51deea83498eeb4eff042151',
#     'name': 'Cocina Mexicana',
#     'location': {'lat': 40.710225636593165,
#      'lng': -74.0118313673788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.710225636593165,
#        'lng': -74.0118313673788}],
#      'distance': 603,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625327540',
#     'hasPerk': False}]}}

# %% [markdown]
# **Get relevant part of JSON and transform it into a pandas dataframe**

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                         name  \
# 0  4bd716bd6798ef3b382c668d       Chipotle Mexican Grill
# 1  51b3b7da498efda7cefb2660  Dahlia's Mexican Restaurant
# 2  554ce3f0498e5e644ef0ab8a       Chipotle Mexican Grill
# 3  503502d6e4b0bd196609a46e       Chipotle Mexican Grill
# 4  552e8f94498e2fd1610bbcb7            mexican boulevard
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...  v-1625327540    False
# 1  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...  v-1625327540    False
# 2  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...  v-1625327540    False
# 3  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...  v-1625327540    False
# 4  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1625327540    False
#
#    location.address                location.crossStreet  location.lat  \
# 0     111 Fulton St                       at William St     40.709927
# 1  353 Greenwich St                                 NaN     40.718754
# 2     325 S End Ave  South End Avenue and Albany Street     40.710703
# 3  275 Greenwich St             btwn Murray & Warren St     40.715043
# 4               NaN                                 NaN     40.718580
#
#    location.lng                            location.labeledLatLngs  \
# 0    -74.006561  [{'label': 'display', 'lat': 40.7099267, 'lng'...
# 1    -74.010337  [{'label': 'display', 'lat': 40.71875385948834...
# 2    -74.016370  [{'label': 'display', 'lat': 40.71070271157653...
# 3    -74.011030  [{'label': 'display', 'lat': 40.71504294817927...
# 4    -74.012222  [{'label': 'display', 'lat': 40.71858025463592...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                928               10038          US      New York
# 1                597               10013          US      New York
# 2                481               10280          US      New York
# 3                363               10007          US      New York
# 4                481                 NaN          US      New York
#
#   location.state location.country  \
# 0             NY    United States
# 1             NY    United States
# 2             NY    United States
# 3             NY    United States
# 4             NY    United States
#
#                            location.formattedAddress venuePage.id  \
# 0  [111 Fulton St (at William St), New York, NY 1...          NaN
# 1  [353 Greenwich St, New York, NY 10013, United ...     88041102
# 2  [325 S End Ave (South End Avenue and Albany St...          NaN
# 3  [275 Greenwich St (btwn Murray & Warren St), N...          NaN
# 4                      [New York, NY, United States]          NaN
#
#              location.neighborhood delivery.id delivery.url  \
# 0                              NaN         NaN          NaN
# 1                              NaN         NaN          NaN
# 2  Battery Park City, New York, NY         NaN          NaN
# 3                              NaN         NaN          NaN
# 4                              NaN         NaN          NaN
#
#   delivery.provider.name delivery.provider.icon.prefix  \
# 0                    NaN                           NaN
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.icon.name
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN

# %% [markdown]
# **Define information of interest and filter dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                           name          categories           address  \
# 0       Chipotle Mexican Grill  Mexican Restaurant     111 Fulton St
# 1  Dahlia's Mexican Restaurant  Mexican Restaurant  353 Greenwich St
# 2       Chipotle Mexican Grill  Mexican Restaurant     325 S End Ave
# 3       Chipotle Mexican Grill  Mexican Restaurant  275 Greenwich St
# 4            mexican boulevard          Food Truck               NaN
# 5          Tex-mexican Express  Mexican Restaurant       63 Reade St
# 6       Chipotle Mexican Grill       Burrito Place      281 Broadway
# 7       Caliente Mexican Grill                None               NaN
# 8              Cocina Mexicana          Food Truck               NaN
#
#                           crossStreet        lat        lng  \
# 0                       at William St  40.709927 -74.006561
# 1                                 NaN  40.718754 -74.010337
# 2  South End Avenue and Albany Street  40.710703 -74.016370
# 3             btwn Murray & Warren St  40.715043 -74.011030
# 4                                 NaN  40.718580 -74.012222
# 5                 Broadway and church  40.714851 -74.006538
# 6                         at Reade St  40.714607 -74.006335
# 7                                 NaN  40.708690 -74.010920
# 8                                 NaN  40.710226 -74.011831
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.7099267, 'lng'...       928      10038  US
# 1  [{'label': 'display', 'lat': 40.71875385948834...       597      10013  US
# 2  [{'label': 'display', 'lat': 40.71070271157653...       481      10280  US
# 3  [{'label': 'display', 'lat': 40.71504294817927...       363      10007  US
# 4  [{'label': 'display', 'lat': 40.71858025463592...       481        NaN  US
# 5  [{'label': 'display', 'lat': 40.71485137939453...       742      10007  US
# 6  [{'label': 'display', 'lat': 40.71460660649931...       760      10007  US
# 7  [{'label': 'display', 'lat': 40.70869, 'lng': ...       790      10271  US
# 8  [{'label': 'display', 'lat': 40.71022563659316...       603        NaN  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
# 2  New York    NY  United States
# 3  New York    NY  United States
# 4  New York    NY  United States
# 5  New York    NY  United States
# 6  New York    NY  United States
# 7  New York    NY  United States
# 8  New York    NY  United States
#
#                                     formattedAddress  \
# 0  [111 Fulton St (at William St), New York, NY 1...
# 1  [353 Greenwich St, New York, NY 10013, United ...
# 2  [325 S End Ave (South End Avenue and Albany St...
# 3  [275 Greenwich St (btwn Murray & Warren St), N...
# 4                      [New York, NY, United States]
# 5  [63 Reade St (Broadway and church), New York, ...
# 6  [281 Broadway (at Reade St), New York, NY 1000...
# 7                [New York, NY 10271, United States]
# 8                      [New York, NY, United States]
#
#                       neighborhood                        id
# 0                              NaN  4bd716bd6798ef3b382c668d
# 1                              NaN  51b3b7da498efda7cefb2660
# 2  Battery Park City, New York, NY  554ce3f0498e5e644ef0ab8a
# 3                              NaN  503502d6e4b0bd196609a46e
# 4                              NaN  552e8f94498e2fd1610bbcb7
# 5                              NaN  4d5eb921d7206ea8b045e0f1
# 6                              NaN  4ee8e058f790a9d738d62d70
# 7                              NaN  5109475fe4b0e6d0ff2b2294
# 8                              NaN  51deea83498eeb4eff042151

# %% [markdown]
# **Let's visualize the Mexican restaurants that are nearby**

# %%
dataframe_filtered.name
# Out:
# 0         Chipotle Mexican Grill
# 1    Dahlia's Mexican Restaurant
# 2         Chipotle Mexican Grill
# 3         Chipotle Mexican Grill
# 4              mexican boulevard
# 5            Tex-mexican Express
# 6         Chipotle Mexican Grill
# 7         Caliente Mexican Grill
# 8                Cocina Mexicana
# Name: name, dtype: object

# %% [markdown]
# #### A. Let's explore the closest Mexican restaurant -- _Chipotle at South End Avenue_

# %%
venue_id = '554ce3f0498e5e644ef0ab8a' # ID of Chipotle, Mexican Restaurant at South End Avenue
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/554ce3f0498e5e644ef0ab8a?client_id=AMDLDMMIEWL1QOOBEGJ5JNHSS2NBE4H0BK230CRAYNIDBGXQ&client_secret=A4UWUFMDVX1MX0JECHVUZZNOWVGCAE5E2JONLHRO1VVUPOY1&oauth_token=&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '554ce3f0498e5e644ef0ab8a',
#  'name': 'Chipotle Mexican Grill',
#  'contact': {'phone': '2122673818',
#   'formattedPhone': '(212) 267-3818',
#   'twitter': 'chipotletweets',
#   'facebook': '1012827052068487',
#   'facebookUsername': 'ChipotleBatteryParkCity',
#   'facebookName': 'Chipotle Mexican Grill'},
#  'location': {'address': '325 S End Ave',
#   'crossStreet': 'South End Avenue and Albany Street',
#   'lat': 40.71070271157653,
#   'lng': -74.01636963147331,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.71070271157653,
#     'lng': -74.01636963147331}],
#   'postalCode': '10280',
#   'cc': 'US',
#   'neighborhood': 'Battery Park City, New York, NY',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['325 S End Ave (South End Avenue and Albany Street)',
#    'New York, NY 10280',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/chipotle-mexican-grill/554ce3f0498e5e644ef0ab8a',
#  'categories': [{'id': '4bf58dd8d48988d1c1941735',
#    'name': 'Mexican Restaurant',
#    'pluralName': 'Mexican Restaurants',
#    'shortName': 'Mexican',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d153941735',
#    'name': 'Burrito Place',
#    'pluralName': 'Burrito Places',
#    'shortName': 'Burritos',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#     'suffix': '.png'}},
#   {'id': '4bf58dd8d48988d151941735',
#    'name': 'Taco Place',
#    'pluralName': 'Taco Places',
#    'shortName': 'Tacos',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 5},
#  'url': 'https://locations.chipotle.com/ny/new-york/325-s-end-ave',
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 39,
#   'groups': [{'type': 'others', 'count': 39, 'items': []}],
#   'summary': '39 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.4,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 30,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://chipotle.com/menu/',
#   'mobileUrl': 'https://chipotle.com/menu/',
#   'externalUrl': 'https://chipotle.com/menu/'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 22,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 22,
#     'items': [{'id': '5e34a08b0e15b0000776c755',
#       'createdAt': 1580507275,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/10695368_RdH5WPayakTPIFEPErVND28f3qrlwhz3rUzXJi076yY.jpg',
#       'width': 1440,
#       'height': 1920,
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'Chipotle is a restaurant that prepares burritos and tacos at reasonable prices. Our Food With Integrity philosophy includes unprocessed, sustainable, nutritious, responsibly raised, and organic foods where possible.',
#  'storeId': '1836',
#  'page': {'pageInfo': {'description': 'Welcome to the official Chipotle Mexican Grill page.\n\nAccept no substitute (or something).',
#    'banner': 'https://is1.4sqi.net/userpix/AXGS40PDM35SEX0X.jpg',
#    'links': {'count': 1, 'items': [{'url': 'http://www.chipotle.com'}]}},
#   'user': {'firstName': 'Chipotle Mexican Grill',
#    'countryCode': 'US',
#    'type': 'chain',
#    'tips': {'count': 31},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1431102448,
#  'tips': {'count': 5,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 5,
#     'items': [{'id': '5af938b73e67414fce2bbacf',
#       'createdAt': 1526282423,
#       'text': "Been there once, won't go again. Staff was NOT friendly but rather pissed off  Music was way too loud. The whole restaurant did not feel clean.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5af938b73e67414fce2bbacf',
#       'lang': 'en',
#       'likes': {'count': 0, 'groups': []},
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'firstName': 'Hefe', 'lastName': 'H', 'countryCode': 'TR'}}]}]},
#  'shortUrl': 'http://4sq.com/1cvHUkn',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 2,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 2,
#     'items': [{'id': '59a864878c35dc3a2e7404c9',
#       'name': 'Chipotles',
#       'description': 'A list of them',
#       'type': 'others',
#       'user': {'firstName': 'Caitlin', 'lastName': 'L', 'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/caitlinrinn/list/chipotles',
#       'canonicalUrl': 'https://foursquare.com/caitlinrinn/list/chipotles',
#       'createdAt': 1504208007,
#       'updatedAt': 1517944138,
#       'followers': {'count': 0},
#       'listItems': {'count': 198,
#        'items': [{'id': 'v554ce3f0498e5e644ef0ab8a',
#          'createdAt': 1509046396}]}},
#      {'id': '5ab291e3851de5460a7bba72',
#       'name': 'COMIDA',
#       'description': '',
#       'type': 'others',
#       'user': {'firstName': 'Fabiana', 'lastName': 'V', 'countryCode': 'BR'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/481546477/list/comida',
#       'canonicalUrl': 'https://foursquare.com/user/481546477/list/comida',
#       'createdAt': 1521652195,
#       'updatedAt': 1533162617,
#       'followers': {'count': 0},
#       'listItems': {'count': 22,
#        'items': [{'id': 'v554ce3f0498e5e644ef0ab8a',
#          'createdAt': 1522427428}]}}]}]},
#  'hours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '10:45 AM–10:00 PM'}],
#     'segments': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–4:00 PM'},
#      {'renderedTime': '9:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '4:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–10:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#      {'renderedTime': '7:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '11:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '11:00 AM–4:00 PM'},
#      {'renderedTime': '6:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '10:45 AM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'No'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Lunch & Dinner',
#     'count': 8,
#     'items': [{'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'}]}]},
#  'bestPhoto': {'id': '5e34a08b0e15b0000776c755',
#   'createdAt': 1580507275,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/10695368_RdH5WPayakTPIFEPErVND28f3qrlwhz3rUzXJi076yY.jpg',
#   'width': 1440,
#   'height': 1920,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '5e34a08b0e15b0000776c755',
#    'value': -12052480},
#   'highlightTextColor': {'photoId': '5e34a08b0e15b0000776c755', 'value': -1},
#   'algoVersion': 3}}

# %% [markdown]
# #### B. Get the closest venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.4

# %%
venue_id = '503502d6e4b0bd196609a46e' # ID of Chipotle, Mexican Restaurant at South End Avenue at Greenwich st
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.8

# %%
venue_id = '4bd716bd6798ef3b382c668d' # ID of Chipotle, Mexican Restaurant  at William st
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.1

# %%
venue_id = '51b3b7da498efda7cefb2660' # ID of Dahlias, Mexican Restaurant  
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.5

# %%
venue_id = '4ee8e058f790a9d738d62d70' # ID of Chipotle, Mexican Restaurant  at Buerito Place
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.0

# %%
venue_id = '51deea83498eeb4eff042151' # ID of Chipotle, Mexican Restaurant  at Buerito Place
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Other restuarents which are not rated are deleted after checking

# %% [markdown]
# #### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 2

# %% [markdown]
# ## **3) Lets Visualize restaurants for Mexican & Japanese food which were explored above.**

# %% [markdown]
# **_Folium_** is a powerful Python library that helps you create several types of Leaflet maps. It is solely developed for the purpose of visualizing geospatial data.
#
# For a defined center, you can also define the intial zoom level into that location when the map is rendered. **_The higher the zoom level the more the map is zoomed into the center_**

# %% [markdown]
# **Japanese restaurants around Conrad Hotel**

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=30) # generate map centred around Japanese


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Japanese',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=1
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_48e0a9cd8fc34f1c924ecd3b8fe9e2c7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_48e0a9cd8fc34f1c924ecd3b8fe9e2c7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_48e0a9cd8fc34f1c924ecd3b8fe9e2c7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_48e0a9cd8fc34f1c924ecd3b8fe9e2c7%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7149555%2C-74.0153365%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2030%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# **Mexican restaurants around Conrad Hotel**

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=30) # generate map centred around Japanese


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Mexican',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        fill=True,
        color='red',
        fill_color='purple',
        fill_opacity=1
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_90de8bcf835e45458c14bd5b785b99e6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_90de8bcf835e45458c14bd5b785b99e6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_90de8bcf835e45458c14bd5b785b99e6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_90de8bcf835e45458c14bd5b785b99e6%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7149555%2C-74.0153365%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2030%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# <a id='item2'></a>
